# %% [markdown]
# <a href="https://colab.research.google.com/github/Jopat2409/com3610_notebooks/blob/main/LUKE_Fine_Tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/studio-ousia/luke/
# Out:
# fatal: destination path 'luke' already exists and is not an empty directory.

# %%
# !apt-get install python3.8
# !ln -sf /usr/bin/python3.8 /usr/bin/python
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3.8 is already the newest version (3.8.20-1+jammy1).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.

# %%
# !python --version
# Out:
# Python 3.8.1

# %%
# %cd /content/luke/
# Out:
# Streaming output truncated to the last 5000 lines.
#   - Installing gitdb (4.0.12)
#   - Installing google-cloud-core (2.4.2)
#   - Installing google-resumable-media (2.7.2)
#   - Installing jaraco-collections (5.1.0)
#   - Installing joblib (1.4.2)
#   - Installing jupyter-server-ydoc (0.8.0)
#   - Installing jupyterlab-server (2.24.0)
#   - Installing jupyterlab-widgets (3.0.13)
#   - Installing lxml (5.3.1)
#   - Installing notebook (6.5.7)
#   - Installing oauthlib (3.2.2)
#   - Installing pathlib-abc (0.1.1)
#   - Installing portend (3.2.0)
#   - Installing preshed (3.0.9)
#   - Installing pydantic (1.8.2): Installing...
#   - Installing regex (2024.11.6)
#   - Installing s3transfer (0.11.4)
#   - Installing sgmllib3k (1.0.0)
#   - Installing smart-open (6.4.0)
#   - Installing srsly (2.4.8)
#   - Installing tomli (2.2.1)
#   - Installing tqdm (4.67.1)
#   - Installing typer (0.4.2)
#   - Installing wasabi (0.10.1)
#   - Installing widgetsnbextension (4.0.13)
#   - Installing yarl (1.9.4)
#   - Installing zc-lockfile (3.0.post1)
#   - Installing regex (2024.11.6)
#   - Installing s3transfer (0.11.4)
#   - Installing sgmllib3k (1.0.0)
#   - Installing smart-open (6.4.0)
#   - Installing srsly (2.4.8)
#   - Installing tomli (2.2.1)
#   - Installing tqdm (4.67.1)
#   - Installing typer (0.4.2)
#   - Installing wasabi (0.10.1)
#   - Installing widgetsnbextension (4.0.13)
#   - Installing yarl (1.9.4)
#   - Installing zc-lockfile (3.0.post1)
#   - Installing pydantic (1.8.2)
#   - Installing regex (2024.11.6)
#   - Installing s3transfer (0.11.4)
#   - Installing sgmllib3k (1.0.0)
#   - Installing smart-open (6.4.0)
#   - Installing srsly (2.4.8)
#   - Installing tomli (2.2.1)
#   - Installing tqdm (4.67.1)
#   - Installing typer (0.4.2)
#   - Installing wasabi (0.10.1)
#   - Installing widgetsnbextension (4.0.13)
#   - Installing yarl (1.9.4)
#   - Installing zc-lockfile (3.0.post1)
#   - Installing aiohttp (3.8.6): Pending...
#   - Installing backports-csv (1.0.7): Pending...
#   - Installing boto3 (1.37.6): Pending...
#   - Installing cherrypy (18.10.0): Pending...
#   - Installing dill (0.3.6): Pending...
#   - Installing docker-pycreds (0.4.0): Pending...
#   - Installing docker-pycreds (0.4.0): Installing...
#   - Installing docker-pycreds (0.4.0): Installing...
#   - Installing dill (0.3.6): Installing...
#   - Installing docker-pycreds (0.4.0): Installing...
#   - Installing boto3 (1.37.6): Pending...
#   - Installing cherrypy (18.10.0): Pending...
#   - Installing dill (0.3.6): Installing...
#   - Installing docker-pycreds (0.4.0): Installing...
#   - Installing backports-csv (1.0.7): Installing...
#   - Installing boto3 (1.37.6): Pending...
#   - Installing cherrypy (18.10.0): Pending...
#   - Installing dill (0.3.6): Installing...
#   - Installing docker-pycreds (0.4.0): Installing...
#   - Installing dill (0.3.6): Installing...
#   - Installing docker-pycreds (0.4.0): Installing...
#   - Installing cherrypy (18.10.0): Installing...
#   - Installing dill (0.3.6): Installing...
#   - Installing docker-pycreds (0.4.0): Installing...
#   - Installing backports-csv (1.0.7): Installing...
#   - Installing boto3 (1.37.6): Pending...
#   - Installing cherrypy (18.10.0): Installing...
#   - Installing dill (0.3.6): Installing...
#   - Installing docker-pycreds (0.4.0): Installing...
#   - Installing aiohttp (3.8.6): Downloading... 0%
#   - Installing backports-csv (1.0.7): Installing...
#   - Installing boto3 (1.37.6): Pending...
#   - Installing cherrypy (18.10.0): Installing...
#   - Installing dill (0.3.6): Installing...
#   - Installing docker-pycreds (0.4.0): Installing...
#   - Installing cherrypy (18.10.0): Installing...
#   - Installing dill (0.3.6): Installing...
#   - Installing docker-pycreds (0.4.0): Installing...
#   - Installing boto3 (1.37.6): Installing...
#   - Installing cherrypy (18.10.0): Installing...
#   - Installing dill (0.3.6): Installing...
#   - Installing docker-pycreds (0.4.0): Installing...
#   - Installing boto3 (1.37.6): Installing...
#   - Installing cherrypy (18.10.0): Installing...
#   - Installing dill (0.3.6): Installing...
#   - Installing docker-pycreds (0.4.0): Installing...
#   - Installing backports-csv (1.0.7)
#   - Installing boto3 (1.37.6): Installing...
#   - Installing cherrypy (18.10.0): Installing...
#   - Installing dill (0.3.6): Installing...
#   - Installing docker-pycreds (0.4.0): Installing...
#   - Installing feedparser (6.0.11): Pending...
#   - Installing feedparser (6.0.11): Pending...
#   - Installing docker-pycreds (0.4.0)
#   - Installing feedparser (6.0.11): Pending...
#   - Installing future (1.0.0): Pending...
#   - Installing future (1.0.0): Pending...
#   - Installing feedparser (6.0.11): Installing...
#   - Installing future (1.0.0): Pending...
#   - Installing future (1.0.0): Installing...
#   - Installing backports-csv (1.0.7)
#   - Installing boto3 (1.37.6): Installing...
#   - Installing cherrypy (18.10.0): Installing...
#   - Installing dill (0.3.6): Installing...
#   - Installing docker-pycreds (0.4.0)
#   - Installing feedparser (6.0.11): Installing...
#   - Installing future (1.0.0): Installing...
#   - Installing aiohttp (3.8.6): Downloading... 60%
#   - Installing backports-csv (1.0.7)
#   - Installing boto3 (1.37.6): Installing...
#   - Installing cherrypy (18.10.0): Installing...
#   - Installing dill (0.3.6): Installing...
#   - Installing docker-pycreds (0.4.0)
#   - Installing feedparser (6.0.11): Installing...
#   - Installing future (1.0.0): Installing...
#   - Installing docker-pycreds (0.4.0)
#   - Installing feedparser (6.0.11): Installing...
#   - Installing future (1.0.0): Installing...
#   - Installing dill (0.3.6)
#   - Installing docker-pycreds (0.4.0)
#   - Installing feedparser (6.0.11): Installing...
#   - Installing future (1.0.0): Installing...
#   - Installing gitpython (3.1.44): Pending...
#   - Installing future (1.0.0): Installing...
#   - Installing gitpython (3.1.44): Pending...
#   - Installing feedparser (6.0.11)
#   - Installing future (1.0.0): Installing...
#   - Installing gitpython (3.1.44): Pending...
#   - Installing google-cloud-storage (2.19.0): Pending...
#   - Installing backports-csv (1.0.7)
#   - Installing boto3 (1.37.6): Installing...
#   - Installing cherrypy (18.10.0): Installing...
#   - Installing dill (0.3.6)
#   - Installing docker-pycreds (0.4.0)
#   - Installing feedparser (6.0.11)
#   - Installing future (1.0.0): Installing...
#   - Installing gitpython (3.1.44): Pending...
#   - Installing google-cloud-storage (2.19.0): Pending...
#   - Installing aiohttp (3.8.6): Downloading... 100%
#   - Installing backports-csv (1.0.7)
#   - Installing boto3 (1.37.6): Installing...
#   - Installing cherrypy (18.10.0): Installing...
#   - Installing dill (0.3.6)
#   - Installing docker-pycreds (0.4.0)
#   - Installing feedparser (6.0.11)
#   - Installing future (1.0.0): Installing...
#   - Installing gitpython (3.1.44): Pending...
#   - Installing google-cloud-storage (2.19.0): Pending...
#   - Installing google-cloud-storage (2.19.0): Pending...
#   - Installing gitpython (3.1.44): Installing...
#   - Installing google-cloud-storage (2.19.0): Pending...
#   - Installing cherrypy (18.10.0): Installing...
#   - Installing dill (0.3.6)
#   - Installing docker-pycreds (0.4.0)
#   - Installing feedparser (6.0.11)
#   - Installing future (1.0.0): Installing...
#   - Installing gitpython (3.1.44): Installing...
#   - Installing google-cloud-storage (2.19.0): Pending...
#   - Installing boto3 (1.37.6)
#   - Installing cherrypy (18.10.0): Installing...
#   - Installing dill (0.3.6)
#   - Installing docker-pycreds (0.4.0)
#   - Installing feedparser (6.0.11)
#   - Installing future (1.0.0): Installing...
#   - Installing gitpython (3.1.44): Installing...
#   - Installing google-cloud-storage (2.19.0): Pending...
#   - Installing huggingface-hub (0.10.1): Pending...
#   - Installing huggingface-hub (0.10.1): Pending...
#   - Installing google-cloud-storage (2.19.0): Installing...
#   - Installing huggingface-hub (0.10.1): Pending...
#   - Installing backports-csv (1.0.7)
#   - Installing boto3 (1.37.6)
#   - Installing cherrypy (18.10.0): Installing...
#   - Installing dill (0.3.6)
#   - Installing docker-pycreds (0.4.0)
#   - Installing feedparser (6.0.11)
#   - Installing future (1.0.0): Installing...
#   - Installing gitpython (3.1.44): Installing...
#   - Installing google-cloud-storage (2.19.0): Installing...
#   - Installing huggingface-hub (0.10.1): Pending...
#   - Installing aiohttp (3.8.6): Installing...
#   - Installing backports-csv (1.0.7)
#   - Installing boto3 (1.37.6)
#   - Installing cherrypy (18.10.0): Installing...
#   - Installing dill (0.3.6)
#   - Installing docker-pycreds (0.4.0)
#   - Installing feedparser (6.0.11)
#   - Installing future (1.0.0): Installing...
#   - Installing gitpython (3.1.44): Installing...
#   - Installing google-cloud-storage (2.19.0): Installing...
#   - Installing huggingface-hub (0.10.1): Pending...
#   - Installing huggingface-hub (0.10.1): Installing...
#   - Installing huggingface-hub (0.10.1): Installing...
#   - Installing google-cloud-storage (2.19.0)
#   - Installing huggingface-hub (0.10.1): Installing...
#   - Installing iniconfig (2.0.0): Pending...
#   - Installing google-cloud-storage (2.19.0)
#   - Installing huggingface-hub (0.10.1): Installing...
#   - Installing iniconfig (2.0.0): Pending...
#   - Installing gitpython (3.1.44)
#   - Installing google-cloud-storage (2.19.0)
#   - Installing huggingface-hub (0.10.1): Installing...
#   - Installing iniconfig (2.0.0): Pending...
#   - Installing ipywidgets (8.1.5): Pending...
#   - Installing ipywidgets (8.1.5): Pending...
#   - Installing iniconfig (2.0.0): Installing...
#   - Installing ipywidgets (8.1.5): Pending...
#   - Installing dill (0.3.6)
#   - Installing docker-pycreds (0.4.0)
#   - Installing feedparser (6.0.11)
#   - Installing future (1.0.0): Installing...
#   - Installing gitpython (3.1.44)
#   - Installing google-cloud-storage (2.19.0)
#   - Installing huggingface-hub (0.10.1): Installing...
#   - Installing iniconfig (2.0.0): Installing...
#   - Installing ipywidgets (8.1.5): Pending...
#   - Installing cherrypy (18.10.0)
#   - Installing dill (0.3.6)
#   - Installing docker-pycreds (0.4.0)
#   - Installing feedparser (6.0.11)
#   - Installing future (1.0.0): Installing...
#   - Installing gitpython (3.1.44)
#   - Installing google-cloud-storage (2.19.0)
#   - Installing huggingface-hub (0.10.1): Installing...
#   - Installing iniconfig (2.0.0): Installing...
#   - Installing ipywidgets (8.1.5): Pending...
#   - Installing jupyter-console (6.6.3): Pending...
#   - Installing jupyter-console (6.6.3): Pending...
#   - Installing ipywidgets (8.1.5): Installing...
#   - Installing jupyter-console (6.6.3): Pending...
#   - Installing ipywidgets (8.1.5): Installing...
#   - Installing jupyter-console (6.6.3): Pending...
#   - Installing iniconfig (2.0.0)
#   - Installing ipywidgets (8.1.5): Installing...
#   - Installing jupyter-console (6.6.3): Pending...
#   - Installing jupyterlab (3.6.8): Pending...
#   - Installing iniconfig (2.0.0)
#   - Installing ipywidgets (8.1.5): Installing...
#   - Installing jupyter-console (6.6.3): Pending...
#   - Installing jupyterlab (3.6.8): Pending...
#   - Installing huggingface-hub (0.10.1)
#   - Installing iniconfig (2.0.0)
#   - Installing ipywidgets (8.1.5): Installing...
#   - Installing jupyter-console (6.6.3): Pending...
#   - Installing jupyterlab (3.6.8): Pending...
#   - Installing langcodes (3.3.0): Pending...
#   - Installing jupyterlab (3.6.8): Pending...
#   - Installing langcodes (3.3.0): Pending...
#   - Installing jupyter-console (6.6.3): Installing...
#   - Installing jupyterlab (3.6.8): Pending...
#   - Installing langcodes (3.3.0): Pending...
#   - Installing langcodes (3.3.0): Pending...
#   - Installing jupyterlab (3.6.8): Downloading... 0%
#   - Installing langcodes (3.3.0): Pending...
#   - Installing jupyterlab (3.6.8): Downloading... 0%
#   - Installing langcodes (3.3.0): Pending...
#   - Installing jupyter-console (6.6.3)
#   - Installing jupyterlab (3.6.8): Downloading... 0%
#   - Installing langcodes (3.3.0): Pending...
#   - Installing nltk (3.9.1): Pending...
#   - Installing nltk (3.9.1): Pending...
#   - Installing langcodes (3.3.0): Downloading... 0%
#   - Installing nltk (3.9.1): Pending...
#   - Installing nltk (3.9.1): Pending...
#   - Installing langcodes (3.3.0): Downloading... 100%
#   - Installing nltk (3.9.1): Pending...
#   - Installing nltk (3.9.1): Pending...
#   - Installing langcodes (3.3.0): Installing...
#   - Installing nltk (3.9.1): Pending...
#   - Installing nltk (3.9.1): Installing...
#   - Installing jupyter-console (6.6.3)
#   - Installing jupyterlab (3.6.8): Downloading... 0%
#   - Installing langcodes (3.3.0): Installing...
#   - Installing nltk (3.9.1): Installing...
#   - Installing ipywidgets (8.1.5)
#   - Installing jupyter-console (6.6.3)
#   - Installing jupyterlab (3.6.8): Downloading... 0%
#   - Installing langcodes (3.3.0): Installing...
#   - Installing nltk (3.9.1): Installing...
#   - Installing pathtools (0.1.2): Pending...
#   - Installing langcodes (3.3.0): Installing...
#   - Installing nltk (3.9.1): Installing...
#   - Installing pathtools (0.1.2): Pending...
#   - Installing jupyterlab (3.6.8): Downloading... 10%
#   - Installing langcodes (3.3.0): Installing...
#   - Installing nltk (3.9.1): Installing...
#   - Installing pathtools (0.1.2): Pending...
#   - Installing backports-csv (1.0.7)
#   - Installing boto3 (1.37.6)
#   - Installing cherrypy (18.10.0)
#   - Installing dill (0.3.6)
#   - Installing docker-pycreds (0.4.0)
#   - Installing feedparser (6.0.11)
#   - Installing future (1.0.0): Installing...
#   - Installing gitpython (3.1.44)
#   - Installing google-cloud-storage (2.19.0)
#   - Installing huggingface-hub (0.10.1)
#   - Installing iniconfig (2.0.0)
#   - Installing ipywidgets (8.1.5)
#   - Installing jupyter-console (6.6.3)
#   - Installing jupyterlab (3.6.8): Downloading... 10%
#   - Installing langcodes (3.3.0): Installing...
#   - Installing nltk (3.9.1): Installing...
#   - Installing pathtools (0.1.2): Pending...
#   - Installing aiohttp (3.8.6)
#   - Installing backports-csv (1.0.7)
#   - Installing boto3 (1.37.6)
#   - Installing cherrypy (18.10.0)
#   - Installing dill (0.3.6)
#   - Installing docker-pycreds (0.4.0)
#   - Installing feedparser (6.0.11)
#   - Installing future (1.0.0): Installing...
#   - Installing gitpython (3.1.44)
#   - Installing google-cloud-storage (2.19.0)
#   - Installing huggingface-hub (0.10.1)
#   - Installing iniconfig (2.0.0)
#   - Installing ipywidgets (8.1.5)
#   - Installing jupyter-console (6.6.3)
#   - Installing jupyterlab (3.6.8): Downloading... 10%
#   - Installing langcodes (3.3.0): Installing...
#   - Installing nltk (3.9.1): Installing...
#   - Installing pathtools (0.1.2): Pending...
#   - Installing gitpython (3.1.44)
#   - Installing google-cloud-storage (2.19.0)
#   - Installing huggingface-hub (0.10.1)
#   - Installing iniconfig (2.0.0)
#   - Installing ipywidgets (8.1.5)
#   - Installing jupyter-console (6.6.3)
#   - Installing jupyterlab (3.6.8): Downloading... 10%
#   - Installing langcodes (3.3.0): Installing...
#   - Installing nltk (3.9.1): Installing...
#   - Installing pathtools (0.1.2): Pending...
#   - Installing future (1.0.0)
#   - Installing gitpython (3.1.44)
#   - Installing google-cloud-storage (2.19.0)
#   - Installing huggingface-hub (0.10.1)
#   - Installing iniconfig (2.0.0)
#   - Installing ipywidgets (8.1.5)
#   - Installing jupyter-console (6.6.3)
#   - Installing jupyterlab (3.6.8): Downloading... 10%
#   - Installing langcodes (3.3.0): Installing...
#   - Installing nltk (3.9.1): Installing...
#   - Installing pathtools (0.1.2): Pending...
#   - Installing pathy (0.11.0): Pending...
#   - Installing pdfminer-six (20240706): Pending...
#   - Installing pathy (0.11.0): Pending...
#   - Installing pdfminer-six (20240706): Pending...
#   - Installing pathtools (0.1.2): Installing...
#   - Installing pathy (0.11.0): Pending...
#   - Installing pdfminer-six (20240706): Pending...
#   - Installing nltk (3.9.1): Installing...
#   - Installing pathtools (0.1.2): Installing...
#   - Installing pathy (0.11.0): Pending...
#   - Installing pdfminer-six (20240706): Pending...
#   - Installing langcodes (3.3.0)
#   - Installing nltk (3.9.1): Installing...
#   - Installing pathtools (0.1.2): Installing...
#   - Installing pathy (0.11.0): Pending...
#   - Installing pdfminer-six (20240706): Pending...
#   - Installing pillow (9.5.0): Pending...
#   - Installing pathy (0.11.0): Pending...
#   - Installing pdfminer-six (20240706): Pending...
#   - Installing pillow (9.5.0): Pending...
#   - Installing pathtools (0.1.2)
#   - Installing pathy (0.11.0): Pending...
#   - Installing pdfminer-six (20240706): Pending...
#   - Installing pillow (9.5.0): Pending...
#   - Installing pluggy (1.5.0): Pending...
#   - Installing pdfminer-six (20240706): Pending...
#   - Installing pillow (9.5.0): Pending...
#   - Installing pluggy (1.5.0): Pending...
#   - Installing pathy (0.11.0): Installing...
#   - Installing pdfminer-six (20240706): Pending...
#   - Installing pillow (9.5.0): Pending...
#   - Installing pluggy (1.5.0): Pending...
#   - Installing pluggy (1.5.0): Installing...
#   - Installing langcodes (3.3.0)
#   - Installing nltk (3.9.1): Installing...
#   - Installing pathtools (0.1.2)
#   - Installing pathy (0.11.0): Installing...
#   - Installing pdfminer-six (20240706): Pending...
#   - Installing pillow (9.5.0): Pending...
#   - Installing pluggy (1.5.0): Installing...
#   - Installing jupyterlab (3.6.8): Downloading... 20%
#   - Installing langcodes (3.3.0)
#   - Installing nltk (3.9.1): Installing...
#   - Installing pathtools (0.1.2)
#   - Installing pathy (0.11.0): Installing...
#   - Installing pdfminer-six (20240706): Pending...
#   - Installing pillow (9.5.0): Pending...
#   - Installing pluggy (1.5.0): Installing...
#   - Installing pluggy (1.5.0): Installing...
#   - Installing pillow (9.5.0): Downloading... 0%
#   - Installing pluggy (1.5.0): Installing...
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3): Pending...
#   - Installing pdfminer-six (20240706): Pending...
#   - Installing pillow (9.5.0): Downloading... 0%
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3): Pending...
#   - Installing pathy (0.11.0)
#   - Installing pdfminer-six (20240706): Pending...
#   - Installing pillow (9.5.0): Downloading... 0%
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3): Pending...
#   - Installing python-docx (1.1.0): Pending...
#   - Installing python-docx (1.1.0): Pending...
#   - Installing promise (2.3): Installing...
#   - Installing python-docx (1.1.0): Pending...
#   - Installing python-docx (1.1.0): Installing...
#   - Installing langcodes (3.3.0)
#   - Installing nltk (3.9.1): Installing...
#   - Installing pathtools (0.1.2)
#   - Installing pathy (0.11.0)
#   - Installing pdfminer-six (20240706): Pending...
#   - Installing pillow (9.5.0): Downloading... 0%
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3): Installing...
#   - Installing python-docx (1.1.0): Installing...
#   - Installing jupyterlab (3.6.8): Downloading... 30%
#   - Installing langcodes (3.3.0)
#   - Installing nltk (3.9.1): Installing...
#   - Installing pathtools (0.1.2)
#   - Installing pathy (0.11.0)
#   - Installing pdfminer-six (20240706): Pending...
#   - Installing pillow (9.5.0): Downloading... 0%
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3): Installing...
#   - Installing python-docx (1.1.0): Installing...
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3): Installing...
#   - Installing python-docx (1.1.0): Installing...
#   - Installing pillow (9.5.0): Downloading... 30%
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3): Installing...
#   - Installing python-docx (1.1.0): Installing...
#   - Installing python-docx (1.1.0): Installing...
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0): Installing...
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing pillow (9.5.0): Downloading... 30%
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0): Installing...
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing pdfminer-six (20240706): Installing...
#   - Installing pillow (9.5.0): Downloading... 30%
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0): Installing...
#   - Installing requests-oauthlib (2.0.0): Pending...
#   - Installing requests-oauthlib (2.0.0): Downloading... 0%
#   - Installing requests-oauthlib (2.0.0): Downloading... 100%
#   - Installing requests-oauthlib (2.0.0): Installing...
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0): Installing...
#   - Installing requests-oauthlib (2.0.0): Installing...
#   - Installing pillow (9.5.0): Downloading... 50%
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0): Installing...
#   - Installing requests-oauthlib (2.0.0): Installing...
#   - Installing langcodes (3.3.0)
#   - Installing nltk (3.9.1): Installing...
#   - Installing pathtools (0.1.2)
#   - Installing pathy (0.11.0)
#   - Installing pdfminer-six (20240706): Installing...
#   - Installing pillow (9.5.0): Downloading... 50%
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0): Installing...
#   - Installing requests-oauthlib (2.0.0): Installing...
#   - Installing jupyterlab (3.6.8): Downloading... 40%
#   - Installing langcodes (3.3.0)
#   - Installing nltk (3.9.1): Installing...
#   - Installing pathtools (0.1.2)
#   - Installing pathy (0.11.0)
#   - Installing pdfminer-six (20240706): Installing...
#   - Installing pillow (9.5.0): Downloading... 50%
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0): Installing...
#   - Installing requests-oauthlib (2.0.0): Installing...
#   - Installing requests-oauthlib (2.0.0)
#   - Installing rich (12.6.0): Pending...
#   - Installing rich (12.6.0): Installing...
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0): Installing...
#   - Installing requests-oauthlib (2.0.0)
#   - Installing rich (12.6.0): Installing...
#   - Installing pillow (9.5.0): Downloading... 80%
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0): Installing...
#   - Installing requests-oauthlib (2.0.0)
#   - Installing rich (12.6.0): Installing...
#   - Installing langcodes (3.3.0)
#   - Installing nltk (3.9.1): Installing...
#   - Installing pathtools (0.1.2)
#   - Installing pathy (0.11.0)
#   - Installing pdfminer-six (20240706): Installing...
#   - Installing pillow (9.5.0): Downloading... 80%
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0): Installing...
#   - Installing requests-oauthlib (2.0.0)
#   - Installing rich (12.6.0): Installing...
#   - Installing jupyterlab (3.6.8): Downloading... 50%
#   - Installing langcodes (3.3.0)
#   - Installing nltk (3.9.1): Installing...
#   - Installing pathtools (0.1.2)
#   - Installing pathy (0.11.0)
#   - Installing pdfminer-six (20240706): Installing...
#   - Installing pillow (9.5.0): Downloading... 80%
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0): Installing...
#   - Installing requests-oauthlib (2.0.0)
#   - Installing rich (12.6.0): Installing...
#   - Installing requests-oauthlib (2.0.0)
#   - Installing rich (12.6.0): Installing...
#   - Installing python-docx (1.1.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing rich (12.6.0): Installing...
#   - Installing sacremoses (0.1.1): Pending...
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing rich (12.6.0): Installing...
#   - Installing sacremoses (0.1.1): Pending...
#   - Installing pillow (9.5.0): Downloading... 100%
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing rich (12.6.0): Installing...
#   - Installing sacremoses (0.1.1): Pending...
#   - Installing langcodes (3.3.0)
#   - Installing nltk (3.9.1): Installing...
#   - Installing pathtools (0.1.2)
#   - Installing pathy (0.11.0)
#   - Installing pdfminer-six (20240706): Installing...
#   - Installing pillow (9.5.0): Downloading... 100%
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing rich (12.6.0): Installing...
#   - Installing sacremoses (0.1.1): Pending...
#   - Installing jupyterlab (3.6.8): Downloading... 70%
#   - Installing langcodes (3.3.0)
#   - Installing nltk (3.9.1): Installing...
#   - Installing pathtools (0.1.2)
#   - Installing pathy (0.11.0)
#   - Installing pdfminer-six (20240706): Installing...
#   - Installing pillow (9.5.0): Downloading... 100%
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing rich (12.6.0): Installing...
#   - Installing sacremoses (0.1.1): Pending...
#   - Installing sacremoses (0.1.1): Installing...
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing rich (12.6.0): Installing...
#   - Installing sacremoses (0.1.1): Installing...
#   - Installing pillow (9.5.0): Installing...
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing rich (12.6.0): Installing...
#   - Installing sacremoses (0.1.1): Installing...
#   - Installing sacremoses (0.1.1): Installing...
#   - Installing rich (12.6.0)
#   - Installing sacremoses (0.1.1): Installing...
#   - Installing scipy (1.7.3): Pending...
#   - Installing langcodes (3.3.0)
#   - Installing nltk (3.9.1): Installing...
#   - Installing pathtools (0.1.2)
#   - Installing pathy (0.11.0)
#   - Installing pdfminer-six (20240706): Installing...
#   - Installing pillow (9.5.0): Installing...
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing rich (12.6.0)
#   - Installing sacremoses (0.1.1): Installing...
#   - Installing scipy (1.7.3): Pending...
#   - Installing jupyterlab (3.6.8): Downloading... 80%
#   - Installing langcodes (3.3.0)
#   - Installing nltk (3.9.1): Installing...
#   - Installing pathtools (0.1.2)
#   - Installing pathy (0.11.0)
#   - Installing pdfminer-six (20240706): Installing...
#   - Installing pillow (9.5.0): Installing...
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing rich (12.6.0)
#   - Installing sacremoses (0.1.1): Installing...
#   - Installing scipy (1.7.3): Pending...
#   - Installing scipy (1.7.3): Downloading... 0%
#   - Installing langcodes (3.3.0)
#   - Installing nltk (3.9.1): Installing...
#   - Installing pathtools (0.1.2)
#   - Installing pathy (0.11.0)
#   - Installing pdfminer-six (20240706): Installing...
#   - Installing pillow (9.5.0): Installing...
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing rich (12.6.0)
#   - Installing sacremoses (0.1.1): Installing...
#   - Installing scipy (1.7.3): Downloading... 0%
#   - Installing jupyterlab (3.6.8): Downloading... 90%
#   - Installing langcodes (3.3.0)
#   - Installing nltk (3.9.1): Installing...
#   - Installing pathtools (0.1.2)
#   - Installing pathy (0.11.0)
#   - Installing pdfminer-six (20240706): Installing...
#   - Installing pillow (9.5.0): Installing...
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing rich (12.6.0)
#   - Installing sacremoses (0.1.1): Installing...
#   - Installing scipy (1.7.3): Downloading... 0%
#   - Installing langcodes (3.3.0)
#   - Installing nltk (3.9.1): Installing...
#   - Installing pathtools (0.1.2)
#   - Installing pathy (0.11.0)
#   - Installing pdfminer-six (20240706): Installing...
#   - Installing pillow (9.5.0): Installing...
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing rich (12.6.0)
#   - Installing sacremoses (0.1.1): Installing...
#   - Installing scipy (1.7.3): Downloading... 0%
#   - Installing jupyterlab (3.6.8): Downloading... 100%
#   - Installing langcodes (3.3.0)
#   - Installing nltk (3.9.1): Installing...
#   - Installing pathtools (0.1.2)
#   - Installing pathy (0.11.0)
#   - Installing pdfminer-six (20240706): Installing...
#   - Installing pillow (9.5.0): Installing...
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing rich (12.6.0)
#   - Installing sacremoses (0.1.1): Installing...
#   - Installing scipy (1.7.3): Downloading... 0%
#   - Installing scipy (1.7.3): Downloading... 0%
#   - Installing sacremoses (0.1.1)
#   - Installing scipy (1.7.3): Downloading... 0%
#   - Installing sentry-sdk (2.22.0): Pending...
#   - Installing sentry-sdk (2.22.0): Installing...
#   - Installing pathtools (0.1.2)
#   - Installing pathy (0.11.0)
#   - Installing pdfminer-six (20240706): Installing...
#   - Installing pillow (9.5.0): Installing...
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing rich (12.6.0)
#   - Installing sacremoses (0.1.1)
#   - Installing scipy (1.7.3): Downloading... 0%
#   - Installing sentry-sdk (2.22.0): Installing...
#   - Installing nltk (3.9.1)
#   - Installing pathtools (0.1.2)
#   - Installing pathy (0.11.0)
#   - Installing pdfminer-six (20240706): Installing...
#   - Installing pillow (9.5.0): Installing...
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing rich (12.6.0)
#   - Installing sacremoses (0.1.1)
#   - Installing scipy (1.7.3): Downloading... 0%
#   - Installing sentry-sdk (2.22.0): Installing...
#   - Installing setproctitle (1.3.5): Pending...
#   - Installing pillow (9.5.0): Installing...
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing rich (12.6.0)
#   - Installing sacremoses (0.1.1)
#   - Installing scipy (1.7.3): Downloading... 0%
#   - Installing sentry-sdk (2.22.0): Installing...
#   - Installing setproctitle (1.3.5): Pending...
#   - Installing pdfminer-six (20240706)
#   - Installing pillow (9.5.0): Installing...
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing rich (12.6.0)
#   - Installing sacremoses (0.1.1)
#   - Installing scipy (1.7.3): Downloading... 0%
#   - Installing sentry-sdk (2.22.0): Installing...
#   - Installing setproctitle (1.3.5): Pending...
#   - Installing shortuuid (1.0.13): Pending...
#   - Installing shortuuid (1.0.13): Installing...
#   - Installing shortuuid (1.0.13): Installing...
#   - Installing setproctitle (1.3.5): Downloading... 0%
#   - Installing shortuuid (1.0.13): Installing...
#   - Installing langcodes (3.3.0)
#   - Installing nltk (3.9.1)
#   - Installing pathtools (0.1.2)
#   - Installing pathy (0.11.0)
#   - Installing pdfminer-six (20240706)
#   - Installing pillow (9.5.0): Installing...
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing rich (12.6.0)
#   - Installing sacremoses (0.1.1)
#   - Installing scipy (1.7.3): Downloading... 0%
#   - Installing sentry-sdk (2.22.0): Installing...
#   - Installing setproctitle (1.3.5): Downloading... 0%
#   - Installing shortuuid (1.0.13): Installing...
#   - Installing jupyterlab (3.6.8): Installing...
#   - Installing langcodes (3.3.0)
#   - Installing nltk (3.9.1)
#   - Installing pathtools (0.1.2)
#   - Installing pathy (0.11.0)
#   - Installing pdfminer-six (20240706)
#   - Installing pillow (9.5.0): Installing...
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing rich (12.6.0)
#   - Installing sacremoses (0.1.1)
#   - Installing scipy (1.7.3): Downloading... 0%
#   - Installing sentry-sdk (2.22.0): Installing...
#   - Installing setproctitle (1.3.5): Downloading... 0%
#   - Installing shortuuid (1.0.13): Installing...
#   - Installing shortuuid (1.0.13): Installing...
#   - Installing setproctitle (1.3.5): Downloading... 100%
#   - Installing shortuuid (1.0.13): Installing...
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12): Pending...
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12): Pending...
#   - Installing setproctitle (1.3.5): Installing...
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12): Pending...
#   - Installing sentry-sdk (2.22.0): Installing...
#   - Installing setproctitle (1.3.5): Installing...
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12): Pending...
#   - Installing scipy (1.7.3): Downloading... 10%
#   - Installing sentry-sdk (2.22.0): Installing...
#   - Installing setproctitle (1.3.5): Installing...
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12): Pending...
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12): Pending...
#   - Installing setproctitle (1.3.5)
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12): Pending...
#   - Installing spacy-loggers (1.0.5): Pending...
#   - Installing spacy-loggers (1.0.5): Pending...
#   - Installing spacy-legacy (3.0.12): Installing...
#   - Installing spacy-loggers (1.0.5): Pending...
#   - Installing spacy-loggers (1.0.5): Installing...
#   - Installing spacy-loggers (1.0.5): Installing...
#   - Installing spacy-legacy (3.0.12)
#   - Installing spacy-loggers (1.0.5): Installing...
#   - Installing thinc (8.0.17): Pending...
#   - Installing thinc (8.0.17): Pending...
#   - Installing spacy-loggers (1.0.5)
#   - Installing thinc (8.0.17): Pending...
#   - Installing threadpoolctl (3.5.0): Pending...
#   - Installing threadpoolctl (3.5.0): Installing...
#   - Installing setproctitle (1.3.5)
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12)
#   - Installing spacy-loggers (1.0.5)
#   - Installing thinc (8.0.17): Pending...
#   - Installing threadpoolctl (3.5.0): Installing...
#   - Installing sentry-sdk (2.22.0)
#   - Installing setproctitle (1.3.5)
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12)
#   - Installing spacy-loggers (1.0.5)
#   - Installing thinc (8.0.17): Pending...
#   - Installing threadpoolctl (3.5.0): Installing...
#   - Installing tokenizers (0.10.3): Pending...
#   - Installing tokenizers (0.10.3): Pending...
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3): Pending...
#   - Installing torch (1.10.2): Pending...
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3): Pending...
#   - Installing torch (1.10.2): Pending...
#   - Installing thinc (8.0.17): Downloading... 0%
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3): Pending...
#   - Installing torch (1.10.2): Pending...
#   - Installing torch (1.10.2): Pending...
#   - Installing tokenizers (0.10.3): Downloading... 0%
#   - Installing torch (1.10.2): Pending...
#   - Installing torch (1.10.2): Downloading... 0%
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3): Downloading... 0%
#   - Installing torch (1.10.2): Downloading... 0%
#   - Installing thinc (8.0.17): Downloading... 100%
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3): Downloading... 0%
#   - Installing torch (1.10.2): Downloading... 0%
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3): Downloading... 0%
#   - Installing torch (1.10.2): Downloading... 0%
#   - Installing thinc (8.0.17): Installing...
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3): Downloading... 0%
#   - Installing torch (1.10.2): Downloading... 0%
#   - Installing torch (1.10.2): Downloading... 0%
#   - Installing tokenizers (0.10.3): Downloading... 40%
#   - Installing torch (1.10.2): Downloading... 0%
#   - Installing sentry-sdk (2.22.0)
#   - Installing setproctitle (1.3.5)
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12)
#   - Installing spacy-loggers (1.0.5)
#   - Installing thinc (8.0.17): Installing...
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3): Downloading... 40%
#   - Installing torch (1.10.2): Downloading... 0%
#   - Installing scipy (1.7.3): Downloading... 20%
#   - Installing sentry-sdk (2.22.0)
#   - Installing setproctitle (1.3.5)
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12)
#   - Installing spacy-loggers (1.0.5)
#   - Installing thinc (8.0.17): Installing...
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3): Downloading... 40%
#   - Installing torch (1.10.2): Downloading... 0%
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing rich (12.6.0)
#   - Installing sacremoses (0.1.1)
#   - Installing scipy (1.7.3): Downloading... 20%
#   - Installing sentry-sdk (2.22.0)
#   - Installing setproctitle (1.3.5)
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12)
#   - Installing spacy-loggers (1.0.5)
#   - Installing thinc (8.0.17): Installing...
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3): Downloading... 40%
#   - Installing torch (1.10.2): Downloading... 0%
#   - Installing pillow (9.5.0)
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing rich (12.6.0)
#   - Installing sacremoses (0.1.1)
#   - Installing scipy (1.7.3): Downloading... 20%
#   - Installing sentry-sdk (2.22.0)
#   - Installing setproctitle (1.3.5)
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12)
#   - Installing spacy-loggers (1.0.5)
#   - Installing thinc (8.0.17): Installing...
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3): Downloading... 40%
#   - Installing torch (1.10.2): Downloading... 0%
#   - Installing torch (1.10.2): Downloading... 0%
#   - Installing tokenizers (0.10.3): Downloading... 90%
#   - Installing torch (1.10.2): Downloading... 0%
#   - Installing torch (1.10.2): Downloading... 0%
#   - Installing tokenizers (0.10.3): Downloading... 100%
#   - Installing torch (1.10.2): Downloading... 0%
#   - Installing torch (1.10.2): Downloading... 0%
#   - Installing tokenizers (0.10.3): Installing...
#   - Installing torch (1.10.2): Downloading... 0%
#   - Installing sentry-sdk (2.22.0)
#   - Installing setproctitle (1.3.5)
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12)
#   - Installing spacy-loggers (1.0.5)
#   - Installing thinc (8.0.17): Installing...
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3): Installing...
#   - Installing torch (1.10.2): Downloading... 0%
#   - Installing scipy (1.7.3): Downloading... 30%
#   - Installing sentry-sdk (2.22.0)
#   - Installing setproctitle (1.3.5)
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12)
#   - Installing spacy-loggers (1.0.5)
#   - Installing thinc (8.0.17): Installing...
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3): Installing...
#   - Installing torch (1.10.2): Downloading... 0%
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3): Installing...
#   - Installing torch (1.10.2): Downloading... 0%
#   - Installing thinc (8.0.17)
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3): Installing...
#   - Installing torch (1.10.2): Downloading... 0%
#   - Installing sentry-sdk (2.22.0)
#   - Installing setproctitle (1.3.5)
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12)
#   - Installing spacy-loggers (1.0.5)
#   - Installing thinc (8.0.17)
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3): Installing...
#   - Installing torch (1.10.2): Downloading... 0%
#   - Installing scipy (1.7.3): Downloading... 40%
#   - Installing sentry-sdk (2.22.0)
#   - Installing setproctitle (1.3.5)
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12)
#   - Installing spacy-loggers (1.0.5)
#   - Installing thinc (8.0.17)
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3): Installing...
#   - Installing torch (1.10.2): Downloading... 0%
#   - Installing torch (1.10.2): Downloading... 1%
#   - Installing sentry-sdk (2.22.0)
#   - Installing setproctitle (1.3.5)
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12)
#   - Installing spacy-loggers (1.0.5)
#   - Installing thinc (8.0.17)
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3): Installing...
#   - Installing torch (1.10.2): Downloading... 1%
#   - Installing scipy (1.7.3): Downloading... 50%
#   - Installing sentry-sdk (2.22.0)
#   - Installing setproctitle (1.3.5)
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12)
#   - Installing spacy-loggers (1.0.5)
#   - Installing thinc (8.0.17)
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3): Installing...
#   - Installing torch (1.10.2): Downloading... 1%
#   - Installing sentry-sdk (2.22.0)
#   - Installing setproctitle (1.3.5)
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12)
#   - Installing spacy-loggers (1.0.5)
#   - Installing thinc (8.0.17)
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3): Installing...
#   - Installing torch (1.10.2): Downloading... 1%
#   - Installing scipy (1.7.3): Downloading... 60%
#   - Installing sentry-sdk (2.22.0)
#   - Installing setproctitle (1.3.5)
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12)
#   - Installing spacy-loggers (1.0.5)
#   - Installing thinc (8.0.17)
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3): Installing...
#   - Installing torch (1.10.2): Downloading... 1%
#   - Installing torch (1.10.2): Downloading... 1%
#   - Installing tokenizers (0.10.3)
#   - Installing torch (1.10.2): Downloading... 1%
#   - Installing sentry-sdk (2.22.0)
#   - Installing setproctitle (1.3.5)
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12)
#   - Installing spacy-loggers (1.0.5)
#   - Installing thinc (8.0.17)
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3)
#   - Installing torch (1.10.2): Downloading... 1%
#   - Installing scipy (1.7.3): Downloading... 70%
#   - Installing sentry-sdk (2.22.0)
#   - Installing setproctitle (1.3.5)
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12)
#   - Installing spacy-loggers (1.0.5)
#   - Installing thinc (8.0.17)
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3)
#   - Installing torch (1.10.2): Downloading... 1%
#   - Installing sentry-sdk (2.22.0)
#   - Installing setproctitle (1.3.5)
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12)
#   - Installing spacy-loggers (1.0.5)
#   - Installing thinc (8.0.17)
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3)
#   - Installing torch (1.10.2): Downloading... 1%
#   - Installing scipy (1.7.3): Downloading... 80%
#   - Installing sentry-sdk (2.22.0)
#   - Installing setproctitle (1.3.5)
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12)
#   - Installing spacy-loggers (1.0.5)
#   - Installing thinc (8.0.17)
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3)
#   - Installing torch (1.10.2): Downloading... 1%
#   - Installing sentry-sdk (2.22.0)
#   - Installing setproctitle (1.3.5)
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12)
#   - Installing spacy-loggers (1.0.5)
#   - Installing thinc (8.0.17)
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3)
#   - Installing torch (1.10.2): Downloading... 1%
#   - Installing scipy (1.7.3): Downloading... 90%
#   - Installing sentry-sdk (2.22.0)
#   - Installing setproctitle (1.3.5)
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12)
#   - Installing spacy-loggers (1.0.5)
#   - Installing thinc (8.0.17)
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3)
#   - Installing torch (1.10.2): Downloading... 1%
#   - Installing torch (1.10.2): Downloading... 3%
#   - Installing sentry-sdk (2.22.0)
#   - Installing setproctitle (1.3.5)
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12)
#   - Installing spacy-loggers (1.0.5)
#   - Installing thinc (8.0.17)
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3)
#   - Installing torch (1.10.2): Downloading... 3%
#   - Installing scipy (1.7.3): Downloading... 100%
#   - Installing sentry-sdk (2.22.0)
#   - Installing setproctitle (1.3.5)
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12)
#   - Installing spacy-loggers (1.0.5)
#   - Installing thinc (8.0.17)
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3)
#   - Installing torch (1.10.2): Downloading... 3%
#   - Installing langcodes (3.3.0)
#   - Installing nltk (3.9.1)
#   - Installing pathtools (0.1.2)
#   - Installing pathy (0.11.0)
#   - Installing pdfminer-six (20240706)
#   - Installing pillow (9.5.0)
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing rich (12.6.0)
#   - Installing sacremoses (0.1.1)
#   - Installing scipy (1.7.3): Downloading... 100%
#   - Installing sentry-sdk (2.22.0)
#   - Installing setproctitle (1.3.5)
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12)
#   - Installing spacy-loggers (1.0.5)
#   - Installing thinc (8.0.17)
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3)
#   - Installing torch (1.10.2): Downloading... 3%
#   - Installing jupyterlab (3.6.8)
#   - Installing langcodes (3.3.0)
#   - Installing nltk (3.9.1)
#   - Installing pathtools (0.1.2)
#   - Installing pathy (0.11.0)
#   - Installing pdfminer-six (20240706)
#   - Installing pillow (9.5.0)
#   - Installing pluggy (1.5.0)
#   - Installing promise (2.3)
#   - Installing python-docx (1.1.0)
#   - Installing requests-oauthlib (2.0.0)
#   - Installing rich (12.6.0)
#   - Installing sacremoses (0.1.1)
#   - Installing scipy (1.7.3): Downloading... 100%
#   - Installing sentry-sdk (2.22.0)
#   - Installing setproctitle (1.3.5)
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12)
#   - Installing spacy-loggers (1.0.5)
#   - Installing thinc (8.0.17)
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3)
#   - Installing torch (1.10.2): Downloading... 3%
#   - Installing torch (1.10.2): Downloading... 5%
#   - Installing sentry-sdk (2.22.0)
#   - Installing setproctitle (1.3.5)
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12)
#   - Installing spacy-loggers (1.0.5)
#   - Installing thinc (8.0.17)
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3)
#   - Installing torch (1.10.2): Downloading... 5%
#   - Installing scipy (1.7.3): Installing...
#   - Installing sentry-sdk (2.22.0)
#   - Installing setproctitle (1.3.5)
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12)
#   - Installing spacy-loggers (1.0.5)
#   - Installing thinc (8.0.17)
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3)
#   - Installing torch (1.10.2): Downloading... 5%
#   - Installing torch (1.10.2): Downloading... 10%
#   - Installing torch (1.10.2): Downloading... 14%
#   - Installing torch (1.10.2): Downloading... 19%
#   - Installing torch (1.10.2): Downloading... 20%
#   - Installing sentry-sdk (2.22.0)
#   - Installing setproctitle (1.3.5)
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12)
#   - Installing spacy-loggers (1.0.5)
#   - Installing thinc (8.0.17)
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3)
#   - Installing torch (1.10.2): Downloading... 20%
#   - Installing scipy (1.7.3)
#   - Installing sentry-sdk (2.22.0)
#   - Installing setproctitle (1.3.5)
#   - Installing shortuuid (1.0.13)
#   - Installing spacy-legacy (3.0.12)
#   - Installing spacy-loggers (1.0.5)
#   - Installing thinc (8.0.17)
#   - Installing threadpoolctl (3.5.0)
#   - Installing tokenizers (0.10.3)
#   - Installing torch (1.10.2): Downloading... 20%
#   - Installing torch (1.10.2): Downloading... 24%
#   - Installing torch (1.10.2): Downloading... 30%
#   - Installing torch (1.10.2): Downloading... 37%
#   - Installing torch (1.10.2): Downloading... 40%
# ...
#   - Installing keras (2.11.0)
#   - Installing libclang (18.1.1)
#   - Installing marisa-trie (0.7.8)
#   - Installing mwparserfromhell (0.6.6)
#   - Installing mypy-extensions (1.0.0)
#   - Installing nodeenv (1.9.1)
#   - Installing opt-einsum (3.4.0)
#   - Installing pathspec (0.12.1)
#   - Installing py-rouge (1.1)
#   - Installing tensorboard (2.11.2)
#   - Installing tensorflow-estimator (2.11.0)
#   - Installing tensorflow-io-gcs-filesystem (0.37.1): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for tensorflow-io-gcs-filesystem (0.37.1)
#
#   at /usr/local/lib/python3.8/site-packages/poetry/installation/chooser.py:74 in choose_for
#        70│
#        71│             links.append(link)
#        72│
#        73│         if not links:
#     →  74│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        75│
#        76│         # Get the best link
#        77│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        78│
#
# Cannot install tensorflow-io-gcs-filesystem.
#
#   - Installing word2number (1.1)
#   - Installing virtualenv (20.21.1)
#   - Installing wrapt (1.17.2)
#       165│
#   - Installing conllu (4.4.1)
#   - Installing datasets (2.10.1)
#   - Installing flatbuffers (25.2.10)
#   - Installing ftfy (6.1.1)
#   - Installing gast (0.4.0)
#   - Installing google-pasta (0.2.0)
#   - Installing identify (2.5.24)
#   - Installing jieba (0.42.1): Preparing...
#   - Installing keras (2.11.0)
#   - Installing libclang (18.1.1)
#   - Installing marisa-trie (0.7.8)
#   - Installing mwparserfromhell (0.6.6)
#   - Installing mypy-extensions (1.0.0)
#   - Installing nodeenv (1.9.1)
#   - Installing opt-einsum (3.4.0)
#   - Installing pathspec (0.12.1)
#   - Installing py-rouge (1.1)
#   - Installing tensorboard (2.11.2)
#   - Installing tensorflow-estimator (2.11.0)
#   - Installing tensorflow-io-gcs-filesystem (0.37.1): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for tensorflow-io-gcs-filesystem (0.37.1)
#
#   at /usr/local/lib/python3.8/site-packages/poetry/installation/chooser.py:74 in choose_for
#        70│
#        71│             links.append(link)
#        72│
#        73│         if not links:
#     →  74│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        75│
#        76│         # Get the best link
#        77│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        78│
#
# Cannot install tensorflow-io-gcs-filesystem.
#
#   - Installing word2number (1.1)
#   - Installing virtualenv (20.21.1)
#   - Installing wrapt (1.17.2)
#       166│             return path
#   - Installing conllu (4.4.1)
#   - Installing datasets (2.10.1)
#   - Installing flatbuffers (25.2.10)
#   - Installing ftfy (6.1.1)
#   - Installing gast (0.4.0)
#   - Installing google-pasta (0.2.0)
#   - Installing identify (2.5.24)
#   - Installing jieba (0.42.1): Preparing...
#   - Installing keras (2.11.0)
#   - Installing libclang (18.1.1)
#   - Installing marisa-trie (0.7.8)
#   - Installing mwparserfromhell (0.6.6)
#   - Installing mypy-extensions (1.0.0)
#   - Installing nodeenv (1.9.1)
#   - Installing opt-einsum (3.4.0)
#   - Installing pathspec (0.12.1)
#   - Installing py-rouge (1.1)
#   - Installing tensorboard (2.11.2)
#   - Installing tensorflow-estimator (2.11.0)
#   - Installing tensorflow-io-gcs-filesystem (0.37.1): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for tensorflow-io-gcs-filesystem (0.37.1)
#
#   at /usr/local/lib/python3.8/site-packages/poetry/installation/chooser.py:74 in choose_for
#        70│
#        71│             links.append(link)
#        72│
#        73│         if not links:
#     →  74│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        75│
#        76│         # Get the best link
#        77│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        78│
#
# Cannot install tensorflow-io-gcs-filesystem.
#
#   - Installing word2number (1.1)
#   - Installing virtualenv (20.21.1)
#   - Installing wrapt (1.17.2)
#       167│
#   - Installing conllu (4.4.1)
#   - Installing datasets (2.10.1)
#   - Installing flatbuffers (25.2.10)
#   - Installing ftfy (6.1.1)
#   - Installing gast (0.4.0)
#   - Installing google-pasta (0.2.0)
#   - Installing identify (2.5.24)
#   - Installing jieba (0.42.1): Preparing...
#   - Installing keras (2.11.0)
#   - Installing libclang (18.1.1)
#   - Installing marisa-trie (0.7.8)
#   - Installing mwparserfromhell (0.6.6)
#   - Installing mypy-extensions (1.0.0)
#   - Installing nodeenv (1.9.1)
#   - Installing opt-einsum (3.4.0)
#   - Installing pathspec (0.12.1)
#   - Installing py-rouge (1.1)
#   - Installing tensorboard (2.11.2)
#   - Installing tensorflow-estimator (2.11.0)
#   - Installing tensorflow-io-gcs-filesystem (0.37.1): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for tensorflow-io-gcs-filesystem (0.37.1)
#
#   at /usr/local/lib/python3.8/site-packages/poetry/installation/chooser.py:74 in choose_for
#        70│
#        71│             links.append(link)
#        72│
#        73│         if not links:
#     →  74│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        75│
#        76│         # Get the best link
#        77│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        78│
#
# Cannot install tensorflow-io-gcs-filesystem.
#
#   - Installing word2number (1.1)
#   - Installing virtualenv (20.21.1)
#   - Installing wrapt (1.17.2)
#       168│     def _prepare_sdist(self, archive: Path, destination: Path | None = None) -> Path:
#   - Installing conllu (4.4.1)
#   - Installing datasets (2.10.1)
#   - Installing flatbuffers (25.2.10)
#   - Installing ftfy (6.1.1)
#   - Installing gast (0.4.0)
#   - Installing google-pasta (0.2.0)
#   - Installing identify (2.5.24)
#   - Installing jieba (0.42.1): Preparing...
#   - Installing keras (2.11.0)
#   - Installing libclang (18.1.1)
#   - Installing marisa-trie (0.7.8)
#   - Installing mwparserfromhell (0.6.6)
#   - Installing mypy-extensions (1.0.0)
#   - Installing nodeenv (1.9.1)
#   - Installing opt-einsum (3.4.0)
#   - Installing pathspec (0.12.1)
#   - Installing py-rouge (1.1)
#   - Installing tensorboard (2.11.2)
#   - Installing tensorflow-estimator (2.11.0)
#   - Installing tensorflow-io-gcs-filesystem (0.37.1): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for tensorflow-io-gcs-filesystem (0.37.1)
#
#   at /usr/local/lib/python3.8/site-packages/poetry/installation/chooser.py:74 in choose_for
#        70│
#        71│             links.append(link)
#        72│
#        73│         if not links:
#     →  74│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        75│
#        76│         # Get the best link
#        77│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        78│
#
# Cannot install tensorflow-io-gcs-filesystem.
#
#   - Installing word2number (1.1)
#   - Installing virtualenv (20.21.1)
#   - Installing wrapt (1.17.2)
#
#   - Installing conllu (4.4.1)
#   - Installing datasets (2.10.1)
#   - Installing flatbuffers (25.2.10)
#   - Installing ftfy (6.1.1)
#   - Installing gast (0.4.0)
#   - Installing google-pasta (0.2.0)
#   - Installing identify (2.5.24)
#   - Installing jieba (0.42.1): Preparing...
#   - Installing keras (2.11.0)
#   - Installing libclang (18.1.1)
#   - Installing marisa-trie (0.7.8)
#   - Installing mwparserfromhell (0.6.6)
#   - Installing mypy-extensions (1.0.0)
#   - Installing nodeenv (1.9.1)
#   - Installing opt-einsum (3.4.0)
#   - Installing pathspec (0.12.1)
#   - Installing py-rouge (1.1)
#   - Installing tensorboard (2.11.2)
#   - Installing tensorflow-estimator (2.11.0)
#   - Installing tensorflow-io-gcs-filesystem (0.37.1): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for tensorflow-io-gcs-filesystem (0.37.1)
#
#   at /usr/local/lib/python3.8/site-packages/poetry/installation/chooser.py:74 in choose_for
#        70│
#        71│             links.append(link)
#        72│
#        73│         if not links:
#     →  74│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        75│
#        76│         # Get the best link
#        77│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        78│
#
# Cannot install tensorflow-io-gcs-filesystem.
#
#   - Installing word2number (1.1)
#   - Installing virtualenv (20.21.1)
#   - Installing wrapt (1.17.2)
# Note: This error originates from the build backend, and is likely not a problem with poetry but with checklist (0.0.11) not supporting PEP 517 builds. You can verify this by running 'pip wheel --no-cache-dir --use-pep517 "checklist (==0.0.11)"'.
#   - Installing conllu (4.4.1)
#   - Installing datasets (2.10.1)
#   - Installing flatbuffers (25.2.10)
#   - Installing ftfy (6.1.1)
#   - Installing gast (0.4.0)
#   - Installing google-pasta (0.2.0)
#   - Installing identify (2.5.24)
#   - Installing jieba (0.42.1): Preparing...
#   - Installing keras (2.11.0)
#   - Installing libclang (18.1.1)
#   - Installing marisa-trie (0.7.8)
#   - Installing mwparserfromhell (0.6.6)
#   - Installing mypy-extensions (1.0.0)
#   - Installing nodeenv (1.9.1)
#   - Installing opt-einsum (3.4.0)
#   - Installing pathspec (0.12.1)
#   - Installing py-rouge (1.1)
#   - Installing tensorboard (2.11.2)
#   - Installing tensorflow-estimator (2.11.0)
#   - Installing tensorflow-io-gcs-filesystem (0.37.1): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for tensorflow-io-gcs-filesystem (0.37.1)
#
#   at /usr/local/lib/python3.8/site-packages/poetry/installation/chooser.py:74 in choose_for
#        70│
#        71│             links.append(link)
#        72│
#        73│         if not links:
#     →  74│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        75│
#        76│         # Get the best link
#        77│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        78│
#
# Cannot install tensorflow-io-gcs-filesystem.
#
#   - Installing word2number (1.1)
#   - Installing virtualenv (20.21.1)
#   - Installing wrapt (1.17.2)
#
#   - Installing conllu (4.4.1)
#   - Installing datasets (2.10.1)
#   - Installing flatbuffers (25.2.10)
#   - Installing ftfy (6.1.1)
#   - Installing gast (0.4.0)
#   - Installing google-pasta (0.2.0)
#   - Installing identify (2.5.24)
#   - Installing jieba (0.42.1): Preparing...
#   - Installing keras (2.11.0)
#   - Installing libclang (18.1.1)
#   - Installing marisa-trie (0.7.8)
#   - Installing mwparserfromhell (0.6.6)
#   - Installing mypy-extensions (1.0.0)
#   - Installing nodeenv (1.9.1)
#   - Installing opt-einsum (3.4.0)
#   - Installing pathspec (0.12.1)
#   - Installing py-rouge (1.1)
#   - Installing tensorboard (2.11.2)
#   - Installing tensorflow-estimator (2.11.0)
#   - Installing tensorflow-io-gcs-filesystem (0.37.1): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for tensorflow-io-gcs-filesystem (0.37.1)
#
#   at /usr/local/lib/python3.8/site-packages/poetry/installation/chooser.py:74 in choose_for
#        70│
#        71│             links.append(link)
#        72│
#        73│         if not links:
#     →  74│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        75│
#        76│         # Get the best link
#        77│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        78│
#
# Cannot install tensorflow-io-gcs-filesystem.
#
#   - Installing word2number (1.1)
#   - Installing virtualenv (20.21.1)
#   - Installing wrapt (1.17.2)
#   - Installing keras (2.11.0)
#   - Installing libclang (18.1.1)
#   - Installing marisa-trie (0.7.8)
#   - Installing mwparserfromhell (0.6.6)
#   - Installing mypy-extensions (1.0.0)
#   - Installing nodeenv (1.9.1)
#   - Installing opt-einsum (3.4.0)
#   - Installing pathspec (0.12.1)
#   - Installing py-rouge (1.1)
#   - Installing tensorboard (2.11.2)
#   - Installing tensorflow-estimator (2.11.0)
#   - Installing tensorflow-io-gcs-filesystem (0.37.1): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for tensorflow-io-gcs-filesystem (0.37.1)
#
#   at /usr/local/lib/python3.8/site-packages/poetry/installation/chooser.py:74 in choose_for
#        70│
#        71│             links.append(link)
#        72│
#        73│         if not links:
#     →  74│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        75│
#        76│         # Get the best link
#        77│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        78│
#
# Cannot install tensorflow-io-gcs-filesystem.
#
#   - Installing word2number (1.1)
#   - Installing virtualenv (20.21.1)
#   - Installing wrapt (1.17.2)
#   - Installing jieba (0.42.1): Installing...
#   - Installing keras (2.11.0)
#   - Installing libclang (18.1.1)
#   - Installing marisa-trie (0.7.8)
#   - Installing mwparserfromhell (0.6.6)
#   - Installing mypy-extensions (1.0.0)
#   - Installing nodeenv (1.9.1)
#   - Installing opt-einsum (3.4.0)
#   - Installing pathspec (0.12.1)
#   - Installing py-rouge (1.1)
#   - Installing tensorboard (2.11.2)
#   - Installing tensorflow-estimator (2.11.0)
#   - Installing tensorflow-io-gcs-filesystem (0.37.1): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for tensorflow-io-gcs-filesystem (0.37.1)
#
#   at /usr/local/lib/python3.8/site-packages/poetry/installation/chooser.py:74 in choose_for
#        70│
#        71│             links.append(link)
#        72│
#        73│         if not links:
#     →  74│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        75│
#        76│         # Get the best link
#        77│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        78│
#
# Cannot install tensorflow-io-gcs-filesystem.
#
#   - Installing word2number (1.1)
#   - Installing virtualenv (20.21.1)
#   - Installing wrapt (1.17.2)
#   - Installing keras (2.11.0)
#   - Installing libclang (18.1.1)
#   - Installing marisa-trie (0.7.8)
#   - Installing mwparserfromhell (0.6.6)
#   - Installing mypy-extensions (1.0.0)
#   - Installing nodeenv (1.9.1)
#   - Installing opt-einsum (3.4.0)
#   - Installing pathspec (0.12.1)
#   - Installing py-rouge (1.1)
#   - Installing tensorboard (2.11.2)
#   - Installing tensorflow-estimator (2.11.0)
#   - Installing tensorflow-io-gcs-filesystem (0.37.1): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for tensorflow-io-gcs-filesystem (0.37.1)
#
#   at /usr/local/lib/python3.8/site-packages/poetry/installation/chooser.py:74 in choose_for
#        70│
#        71│             links.append(link)
#        72│
#        73│         if not links:
#     →  74│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        75│
#        76│         # Get the best link
#        77│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        78│
#
# Cannot install tensorflow-io-gcs-filesystem.
#
#   - Installing word2number (1.1)
#   - Installing virtualenv (20.21.1)
#   - Installing wrapt (1.17.2)
#   - Installing jieba (0.42.1)
#   - Installing keras (2.11.0)
#   - Installing libclang (18.1.1)
#   - Installing marisa-trie (0.7.8)
#   - Installing mwparserfromhell (0.6.6)
#   - Installing mypy-extensions (1.0.0)
#   - Installing nodeenv (1.9.1)
#   - Installing opt-einsum (3.4.0)
#   - Installing pathspec (0.12.1)
#   - Installing py-rouge (1.1)
#   - Installing tensorboard (2.11.2)
#   - Installing tensorflow-estimator (2.11.0)
#   - Installing tensorflow-io-gcs-filesystem (0.37.1): Failed
#
#   RuntimeError
#
#   Unable to find installation candidates for tensorflow-io-gcs-filesystem (0.37.1)
#
#   at /usr/local/lib/python3.8/site-packages/poetry/installation/chooser.py:74 in choose_for
#        70│
#        71│             links.append(link)
#        72│
#        73│         if not links:
#     →  74│             raise RuntimeError(f"Unable to find installation candidates for {package}")
#        75│
#        76│         # Get the best link
#        77│         chosen = max(links, key=lambda link: self._sort_key(package, link))
#        78│
#
# Cannot install tensorflow-io-gcs-filesystem.
#
#   - Installing word2number (1.1)
#   - Installing virtualenv (20.21.1)
#   - Installing wrapt (1.17.2)

# %%
# !wget https://raw.githubusercontent.com/synalp/NER/master/corpus/CoNLL-2003/eng.train
# !wget https://raw.githubusercontent.com/synalp/NER/master/corpus/CoNLL-2003/eng.testa


# %set_env TRANSFORMERS_MODEL_NAME="studio-ousia/luke-large"
# %set_env TRAIN_DATA_PATH="/content/luke/eng.train"
# %set_env VALIDATION_DATA_PATH="/content/luke/eng.testa"
# Out:
# --2025-03-05 05:00:24--  https://raw.githubusercontent.com/synalp/NER/master/corpus/CoNLL-2003/eng.train
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3281528 (3.1M) [text/plain]
# Saving to: ‘eng.train’
#
# eng.train           100%[===================>]   3.13M  18.6MB/s    in 0.2s
#
# 2025-03-05 05:00:25 (18.6 MB/s) - ‘eng.train’ saved [3281528/3281528]
#
# --2025-03-05 05:00:25--  https://raw.githubusercontent.com/synalp/NER/master/corpus/CoNLL-2003/eng.testa
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 827012 (808K) [text/plain]
# Saving to: ‘eng.testa’
#
# eng.testa           100%[===================>] 807.63K  --.-KB/s    in 0.1s
#
# 2025-03-05 05:00:25 (6.70 MB/s) - ‘eng.testa’ saved [827012/827012]
#
# env: TRANSFORMERS_MODEL_NAME="studio-ousia/luke-large"
# env: TRAIN_DATA_PATH="/content/luke/eng.train"
# env: VALIDATION_DATA_PATH="/content/luke/eng.testa"

# %%
# %pip install allennlp
# Out:
# Collecting allennlp
#   Downloading allennlp-2.10.1-py3-none-any.whl (730 kB)
#      |████████████████████████████████| 730 kB 1.9 MB/s
# Collecting filelock<3.8,>=3.3
#   Downloading filelock-3.7.1-py3-none-any.whl (10 kB)
# Collecting typer>=0.4.1
#   Downloading typer-0.15.2-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 3.1 MB/s
# Collecting tqdm>=4.62
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 7.9 MB/s
# Collecting numpy>=1.21.4
#   Downloading numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      |████████████████████████████████| 17.3 MB 22 kB/s
# Collecting traitlets>5.1.1
#   Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 4.5 MB/s
# Requirement already satisfied: more-itertools>=8.12.0 in /usr/local/lib/python3.8/site-packages (from allennlp) (10.5.0)
# Collecting fairscale==0.4.6
#   Downloading fairscale-0.4.6.tar.gz (248 kB)
#      |████████████████████████████████| 248 kB 41.5 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
# Collecting lmdb>=1.2.1
#   Downloading lmdb-1.6.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (294 kB)
#      |████████████████████████████████| 294 kB 48.3 MB/s
# Collecting scipy>=1.7.3
#   Downloading scipy-1.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#      |████████████████████████████████| 34.5 MB 22 kB/s
# Collecting pytest>=6.2.5
#   Downloading pytest-8.3.5-py3-none-any.whl (343 kB)
#      |████████████████████████████████| 343 kB 42.7 MB/s
# Collecting dill>=0.3.4
#   Downloading dill-0.3.9-py3-none-any.whl (119 kB)
#      |████████████████████████████████| 119 kB 47.7 MB/s
# Collecting termcolor==1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting scikit-learn>=1.0.1
#   Downloading scikit_learn-1.3.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.1 MB)
#      |████████████████████████████████| 11.1 MB 35.9 MB/s
# Collecting wandb<0.13.0,>=0.10.0
#   Downloading wandb-0.12.21-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 39.6 MB/s
# Collecting tensorboardX>=1.2
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 10.8 MB/s
# Collecting jsonnet>=0.10.0; sys_platform != "win32"
#   Downloading jsonnet-0.20.0.tar.gz (594 kB)
#      |████████████████████████████████| 594 kB 49.8 MB/s
# Collecting protobuf<4.0.0,>=3.12.0
#   Downloading protobuf-3.20.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 44.9 MB/s
# Collecting nltk>=3.6.5
#   Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 46.6 MB/s
# Collecting huggingface-hub>=0.0.16
#   Downloading huggingface_hub-0.29.1-py3-none-any.whl (468 kB)
#      |████████████████████████████████| 468 kB 41.9 MB/s
# Collecting base58>=2.1.1
#   Downloading base58-2.1.1-py3-none-any.whl (5.6 kB)
# Collecting spacy<3.4,>=2.1.0
#   Downloading spacy-3.3.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.5 MB)
#      |████████████████████████████████| 6.5 MB 43.8 MB/s
# Collecting torchvision<0.14.0,>=0.8.1
#   Downloading torchvision-0.13.1-cp38-cp38-manylinux1_x86_64.whl (19.1 MB)
#      |████████████████████████████████| 19.1 MB 1.3 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#      |████████████████████████████████| 897 kB 41.3 MB/s
# Collecting transformers<4.21,>=4.1
#   Downloading transformers-4.20.1-py3-none-any.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 44.8 MB/s
# Collecting cached-path<1.2.0,>=1.1.3
#   Downloading cached_path-1.1.6-py3-none-any.whl (26 kB)
# Collecting torch<1.13.0,>=1.10.0
#   Downloading torch-1.12.1-cp38-cp38-manylinux1_x86_64.whl (776.3 MB)
#      |████████████████████████████████| 776.3 MB 864 bytes/s
# Collecting sentencepiece>=0.1.96
#   Downloading sentencepiece-0.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 39.8 MB/s
# Collecting h5py>=3.6.0
#   Downloading h5py-3.11.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#      |████████████████████████████████| 5.3 MB 42.6 MB/s
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.8/site-packages (from allennlp) (2.32.3)
# Collecting typing-extensions>=3.7.4.3
#   Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Collecting click>=8.0.0
#   Downloading click-8.1.8-py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 8.0 MB/s
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.8/site-packages (from typer>=0.4.1->allennlp) (1.5.4)
# Collecting rich>=10.11.0
#   Downloading rich-13.9.4-py3-none-any.whl (242 kB)
#      |████████████████████████████████| 242 kB 54.3 MB/s
# Requirement already satisfied: tomli>=1; python_version < "3.11" in /usr/local/lib/python3.8/site-packages (from pytest>=6.2.5->allennlp) (2.2.1)
# Collecting exceptiongroup>=1.0.0rc8; python_version < "3.11"
#   Downloading exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Collecting iniconfig
#   Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Collecting pluggy<2,>=1.5
#   Downloading pluggy-1.5.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/site-packages (from pytest>=6.2.5->allennlp) (24.2)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Collecting joblib>=1.1.1
#   Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#      |████████████████████████████████| 301 kB 45.3 MB/s
# Collecting promise<3,>=2.0
#   Downloading promise-2.3.tar.gz (19 kB)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.13-py3-none-any.whl (10 kB)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
#      |████████████████████████████████| 207 kB 50.6 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/site-packages (from wandb<0.13.0,>=0.10.0->allennlp) (45.2.0.post20200210)
# Collecting psutil>=5.0.0
#   Downloading psutil-7.0.0-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (277 kB)
#      |████████████████████████████████| 277 kB 50.7 MB/s
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-2.22.0-py2.py3-none-any.whl (325 kB)
#      |████████████████████████████████| 325 kB 42.7 MB/s
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.8/site-packages (from wandb<0.13.0,>=0.10.0->allennlp) (1.14.0)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting PyYAML
#   Downloading PyYAML-6.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (746 kB)
#      |████████████████████████████████| 746 kB 56.9 MB/s
# Collecting setproctitle
#   Downloading setproctitle-1.3.5-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# Collecting regex>=2021.8.3
#   Downloading regex-2024.11.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (785 kB)
#      |████████████████████████████████| 785 kB 39.8 MB/s
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2025.2.0-py3-none-any.whl (184 kB)
#      |████████████████████████████████| 184 kB 51.6 MB/s
# Collecting thinc<8.1.0,>=8.0.14
#   Downloading thinc-8.0.17-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (671 kB)
#      |████████████████████████████████| 671 kB 39.9 MB/s
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.11-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
#      |████████████████████████████████| 10.2 MB 43.5 MB/s
# Collecting jinja2
#   Downloading jinja2-3.1.5-py3-none-any.whl (134 kB)
#      |████████████████████████████████| 134 kB 51.8 MB/s
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.9
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.9-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (154 kB)
#      |████████████████████████████████| 154 kB 49.7 MB/s
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.4.1-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 45.5 MB/s
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Collecting wasabi<1.1.0,>=0.9.1
#   Downloading wasabi-0.10.1-py3-none-any.whl (26 kB)
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (494 kB)
#      |████████████████████████████████| 494 kB 47.0 MB/s
# Collecting smart-open<7.0.0,>=5.2.1
#   Downloading smart_open-6.4.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 5.0 MB/s
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.11.tar.gz (10 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.12.tar.gz (13 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting pathy>=0.3.5
#   Downloading pathy-0.11.0-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 4.3 MB/s
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp38-cp38-manylinux2014_x86_64.whl (13.7 MB)
#      |████████████████████████████████| 13.7 MB 44.8 MB/s
# Collecting pillow!=8.3.*,>=5.3.0
#   Downloading pillow-10.4.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 37.6 MB/s
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 49.2 MB/s
# Collecting boto3<2.0,>=1.0
#   Downloading boto3-1.37.6-py3-none-any.whl (139 kB)
#      |████████████████████████████████| 139 kB 56.5 MB/s
# Collecting google-cloud-storage<3.0,>=1.32.0
#   Downloading google_cloud_storage-2.19.0-py2.py3-none-any.whl (131 kB)
#      |████████████████████████████████| 131 kB 51.4 MB/s
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.8/site-packages (from requests>=2.28->allennlp) (1.25.8)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/site-packages (from requests>=2.28->allennlp) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/site-packages (from requests>=2.28->allennlp) (2019.11.28)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/site-packages (from requests>=2.28->allennlp) (3.4.1)
# Collecting pygments<3.0.0,>=2.13.0
#   Downloading pygments-2.19.1-py3-none-any.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 42.2 MB/s
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      |████████████████████████████████| 87 kB 7.2 MB/s
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.4 MB/s
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26 kB)
# Collecting language-data>=1.2
#   Downloading language_data-1.3.0-py3-none-any.whl (5.4 MB)
#      |████████████████████████████████| 5.4 MB 31.8 MB/s
# Collecting pathlib-abc==0.1.1
#   Downloading pathlib_abc-0.1.1-py3-none-any.whl (23 kB)
# Collecting botocore<1.38.0,>=1.37.6
#   Downloading botocore-1.37.6-py3-none-any.whl (13.4 MB)
#      |████████████████████████████████| 13.4 MB 30.7 MB/s
# Collecting s3transfer<0.12.0,>=0.11.0
#   Downloading s3transfer-0.11.4-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 3.4 MB/s
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting google-api-core<3.0.0dev,>=2.15.0
#   Downloading google_api_core-2.24.1-py3-none-any.whl (160 kB)
#      |████████████████████████████████| 160 kB 24.4 MB/s
# Collecting google-auth<3.0dev,>=2.26.1
#   Downloading google_auth-2.38.0-py2.py3-none-any.whl (210 kB)
#      |████████████████████████████████| 210 kB 50.0 MB/s
# Collecting google-resumable-media>=2.7.2
#   Downloading google_resumable_media-2.7.2-py2.py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 9.2 MB/s
# Collecting google-crc32c<2.0dev,>=1.0
#   Downloading google_crc32c-1.5.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (32 kB)
# Collecting google-cloud-core<3.0dev,>=2.3.0
#   Downloading google_cloud_core-2.4.2-py2.py3-none-any.whl (29 kB)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Collecting marisa-trie>=1.1.0
#   Downloading marisa_trie-1.2.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 40.0 MB/s
# Collecting python-dateutil<3.0.0,>=2.1
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#      |████████████████████████████████| 229 kB 54.3 MB/s
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2
#   Downloading googleapis_common_protos-1.69.0-py2.py3-none-any.whl (169 kB)
#      |████████████████████████████████| 169 kB 51.8 MB/s
# Collecting proto-plus<2.0.0dev,>=1.22.3
#   Downloading proto_plus-1.26.0-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 7.3 MB/s
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 53.2 MB/s
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Collecting pyasn1<0.7.0,>=0.4.6
#   Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 1.8 MB/s
# Building wheels for collected packages: fairscale, termcolor, jsonnet, promise, pathtools, cymem, murmurhash
#   Building wheel for fairscale (PEP 517) ... done
#   Created wheel for fairscale: filename=fairscale-0.4.6-py3-none-any.whl size=307221 sha256=f1672195ed0283b44d7b875115539385d3fd3713e5c0aa42436651e2ab42a5c0
#   Stored in directory: /root/.cache/pip/wheels/77/4c/a4/f6c0eec2ec5c8ffca075e62b0329801f862e1f1b71422f456b
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4830 sha256=0e54e17ca97c3dc156c776fb6f5db619605eb867d455eede3830b2d621a0f9e1
#   Stored in directory: /root/.cache/pip/wheels/a0/16/9c/5473df82468f958445479c59e784896fa24f4a5fc024b0f501
#   Building wheel for jsonnet (setup.py) ... done
#   Created wheel for jsonnet: filename=jsonnet-0.20.0-cp38-cp38-linux_x86_64.whl size=6411166 sha256=1aaab092e1dfddf466c0bbc7a6cbfe0abe30d1ccd5539ce178164bb725df0d6a
#   Stored in directory: /root/.cache/pip/wheels/42/9b/3d/e95f85de3c2757cc5fd0791c0d18695a429e0f5745e0149802
#   Building wheel for promise (setup.py) ... done
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21495 sha256=8c40f08a058a0fa2d6411957f0fa1d965ee2a239ed66df93c86c7c63bdc915af
#   Stored in directory: /root/.cache/pip/wheels/54/aa/01/724885182f93150035a2a91bce34a12877e8067a97baaf5dc8
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8784 sha256=c4bb67b8cd70d58a3172eeb5bd48431b46367bbb49ca88b90252728bda88d2c0
#   Stored in directory: /root/.cache/pip/wheels/4c/8e/7e/72fbc243e1aeecae64a96875432e70d4e92f3d2d18123be004
#   Building wheel for cymem (PEP 517) ... done
#   Created wheel for cymem: filename=cymem-2.0.11-cp38-cp38-linux_x86_64.whl size=191912 sha256=2617a4485a8fd07951e3b48f5f557d2a0e99e3bcb6e184b42e2fcfd5632b08ef
#   Stored in directory: /root/.cache/pip/wheels/a9/45/9e/e01643f1bcc044859f97c48abbf20eeb61d96199e30d2bd919
#   Building wheel for murmurhash (PEP 517) ... done
#   Created wheel for murmurhash: filename=murmurhash-1.0.12-cp38-cp38-linux_x86_64.whl size=117284 sha256=d6330815b714843e2578ee15c1c13275f50416b2d21d5c772d818ee10c88218c
#   Stored in directory: /root/.cache/pip/wheels/e9/11/9a/cf7bd1a6798e6a8f077cdc112205d2aa0eb43af139b86dc8af
# Successfully built fairscale termcolor jsonnet promise pathtools cymem murmurhash
# ERROR: virtualenv 20.29.2 has requirement filelock<4,>=3.12.2, but you'll have filelock 3.7.1 which is incompatible.
# ERROR: sentry-sdk 2.22.0 has requirement urllib3>=1.26.11, but you'll have urllib3 1.25.8 which is incompatible.
# ERROR: spacy 3.3.3 has requirement typer<0.5.0,>=0.3.0, but you'll have typer 0.15.2 which is incompatible.
# ERROR: spacy 3.3.3 has requirement typing-extensions<4.6.0,>=3.7.4.1, but you'll have typing-extensions 4.12.2 which is incompatible.
# ERROR: cached-path 1.1.6 has requirement huggingface-hub<0.11.0,>=0.8.1, but you'll have huggingface-hub 0.29.1 which is incompatible.
# ERROR: cached-path 1.1.6 has requirement rich<13.0,>=12.1, but you'll have rich 13.9.4 which is incompatible.
# Installing collected packages: filelock, typing-extensions, click, pygments, mdurl, markdown-it-py, rich, typer, tqdm, numpy, traitlets, torch, fairscale, lmdb, scipy, exceptiongroup, iniconfig, pluggy, pytest, dill, termcolor, threadpoolctl, joblib, scikit-learn, promise, pathtools, shortuuid, smmap, gitdb, GitPython, psutil, protobuf, sentry-sdk, docker-pycreds, PyYAML, setproctitle, wandb, tensorboardX, jsonnet, regex, nltk, fsspec, huggingface-hub, base58, blis, murmurhash, cymem, preshed, wasabi, catalogue, srsly, pydantic, thinc, MarkupSafe, jinja2, spacy-legacy, marisa-trie, language-data, langcodes, spacy-loggers, smart-open, pathlib-abc, pathy, spacy, pillow, torchvision, sacremoses, tokenizers, transformers, python-dateutil, jmespath, botocore, s3transfer, boto3, pyasn1, pyasn1-modules, rsa, cachetools, google-auth, googleapis-common-protos, proto-plus, google-api-core, google-crc32c, google-resumable-media, google-cloud-core, google-cloud-storage, cached-path, sentencepiece, h5py, allennlp
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.16.1
#     Uninstalling filelock-3.16.1:
#       Successfully uninstalled filelock-3.16.1
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.42.1
#     Uninstalling tqdm-4.42.1:
#       Successfully uninstalled tqdm-4.42.1
# Successfully installed GitPython-3.1.44 MarkupSafe-2.1.5 PyYAML-6.0.2 allennlp-2.10.1 base58-2.1.1 blis-0.7.11 boto3-1.37.6 botocore-1.37.6 cached-path-1.1.6 cachetools-5.5.2 catalogue-2.0.10 click-8.1.8 cymem-2.0.11 dill-0.3.9 docker-pycreds-0.4.0 exceptiongroup-1.2.2 fairscale-0.4.6 filelock-3.7.1 fsspec-2025.2.0 gitdb-4.0.12 google-api-core-2.24.1 google-auth-2.38.0 google-cloud-core-2.4.2 google-cloud-storage-2.19.0 google-crc32c-1.5.0 google-resumable-media-2.7.2 googleapis-common-protos-1.69.0 h5py-3.11.0 huggingface-hub-0.29.1 iniconfig-2.0.0 jinja2-3.1.5 jmespath-1.0.1 joblib-1.4.2 jsonnet-0.20.0 langcodes-3.4.1 language-data-1.3.0 lmdb-1.6.2 marisa-trie-1.2.1 markdown-it-py-3.0.0 mdurl-0.1.2 murmurhash-1.0.12 nltk-3.9.1 numpy-1.24.4 pathlib-abc-0.1.1 pathtools-0.1.2 pathy-0.11.0 pillow-10.4.0 pluggy-1.5.0 preshed-3.0.9 promise-2.3 proto-plus-1.26.0 protobuf-3.20.3 psutil-7.0.0 pyasn1-0.6.1 pyasn1-modules-0.4.1 pydantic-1.8.2 pygments-2.19.1 pytest-8.3.5 python-dateutil-2.9.0.post0 regex-2024.11.6 rich-13.9.4 rsa-4.9 s3transfer-0.11.4 sacremoses-0.1.1 scikit-learn-1.3.2 scipy-1.10.1 sentencepiece-0.2.0 sentry-sdk-2.22.0 setproctitle-1.3.5 shortuuid-1.0.13 smart-open-6.4.0 smmap-5.0.2 spacy-3.3.3 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 tensorboardX-2.6.2.2 termcolor-1.1.0 thinc-8.0.17 threadpoolctl-3.5.0 tokenizers-0.12.1 torch-1.12.1 torchvision-0.13.1 tqdm-4.67.1 traitlets-5.14.3 transformers-4.20.1 typer-0.15.2 typing-extensions-4.12.2 wandb-0.12.21 wasabi-0.10.1

# %%
# !allennlp train examples/ner/configs/transformers_luke_with_entity_aware_attention.jsonnet -s results/ner/luke-large --include-package examples -o '{"trainer": {"cuda_device": 0,"use_amp": true}'
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/allennlp", line 5, in <module>
#     from allennlp.__main__ import run
#   File "/usr/local/lib/python3.8/site-packages/allennlp/__init__.py", line 11, in <module>
#     import transformers, spacy, torch, numpy  # noqa
#   File "/usr/local/lib/python3.8/site-packages/spacy/__init__.py", line 14, in <module>
#     from . import pipeline  # noqa: F401
#   File "/usr/local/lib/python3.8/site-packages/spacy/pipeline/__init__.py", line 1, in <module>
#     from .attributeruler import AttributeRuler
#   File "/usr/local/lib/python3.8/site-packages/spacy/pipeline/attributeruler.py", line 6, in <module>
#     from .pipe import Pipe
#   File "spacy/pipeline/pipe.pyx", line 1, in init spacy.pipeline.pipe
#   File "spacy/vocab.pyx", line 1, in init spacy.vocab
#   File "/usr/local/lib/python3.8/site-packages/spacy/tokens/__init__.py", line 1, in <module>
#     from .doc import Doc
#   File "spacy/tokens/doc.pyx", line 36, in init spacy.tokens.doc
#   File "/usr/local/lib/python3.8/site-packages/spacy/schemas.py", line 216, in <module>
#     class TokenPattern(BaseModel):
#   File "pydantic/main.py", line 299, in pydantic.main.ModelMetaclass.__new__
#   File "pydantic/fields.py", line 411, in pydantic.fields.ModelField.infer
#   File "pydantic/fields.py", line 342, in pydantic.fields.ModelField.__init__
#   File "pydantic/fields.py", line 451, in pydantic.fields.ModelField.prepare
#   File "pydantic/fields.py", line 545, in pydantic.fields.ModelField._type_analysis
#   File "pydantic/fields.py", line 550, in pydantic.fields.ModelField._type_analysis
#   File "/usr/local/lib/python3.8/typing.py", line 771, in __subclasscheck__
#     return issubclass(cls, self.__origin__)
# TypeError: issubclass() arg 1 must be a class
