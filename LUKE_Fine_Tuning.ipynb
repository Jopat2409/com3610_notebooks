# %% [markdown]
# <a href="https://colab.research.google.com/github/Jopat2409/com3610_notebooks/blob/main/LUKE_Fine_Tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/studio-ousia/luke/
# Out:
# Cloning into 'luke'...
# remote: Enumerating objects: 3425, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 3425 (delta 15), reused 24 (delta 9), pack-reused 3390 (from 1)
# Receiving objects: 100% (3425/3425), 4.19 MiB | 8.39 MiB/s, done.
# Resolving deltas: 100% (2161/2161), done.

# %%
# %cd /content/luke
# %pip install poetry
# !poetry lock --no-cache --regenerate
# !poetry install
# Out:
# /content/luke
# ...
# The "poetry.dev-dependencies" section is deprecated and will be removed in a future version. Use "poetry.group.dev.dependencies" instead.
# The currently activated Python version 3.11.11 is not supported by the project (^3.7.1,<3.11).
# Trying to find and use a compatible version.
# Using python3.10 (3.10.12)
# Updating dependencies
# Resolving dependencies... (0.9s)The "poetry.dev-dependencies" section is deprecated and will be removed in a future version. Use "poetry.group.dev.dependencies" instead.
# Resolving dependencies... (4.0s)The "poetry.dev-dependencies" section is deprecated and will be removed in a future version. Use "poetry.group.dev.dependencies" instead.
# Resolving dependencies... (7.2s)The "poetry.dev-dependencies" section is deprecated and will be removed in a future version. Use "poetry.group.dev.dependencies" instead.
# ...
